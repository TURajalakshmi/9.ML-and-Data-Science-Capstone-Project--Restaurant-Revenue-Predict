# %%
import pandas as pd
import numpy as np
import seaborn as sns
import time
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("mall_rental_data.csv")
dataset
# Out:
#     Shop_ID           Mall_Name       City  Floor  Shop_Size_sqft  \
# 0      S001           Lulu Mall      Delhi      2             352
# 1      S002          Forum Mall    Chennai      4            2961
# 2      S003          VR Chennai     Mumbai      0            1402
# 3      S004          Forum Mall     Mumbai      4            1849
# 4      S005          Forum Mall  Bangalore      3            1400
# ..      ...                 ...        ...    ...             ...
# 195    S196          VR Chennai      Kochi      4            1430
# 196    S197          VR Chennai      Kochi      4            2205
# 197    S198  Phoenix Marketcity    Chennai      4             774
# 198    S199          Forum Mall  Bangalore      4            2040
# 199    S200           Lulu Mall      Delhi      4            1426
#
#      Footfall_per_day  Nearby_Brands  Has_Food_Court  Monthly_Sales   Rent
# 0                6311              2               0         962727  67310
# 1                 802             16               0         549722  45221
# 2                1138              9               0        1783693   3704
# 3                 555             12               0         608924  68503
# 4                9217             13               1        1834033  85666
# ..                ...            ...             ...            ...    ...
# 195               845              3               1        1352549  44571
# 196              9054             10               0        1381673  65858
# 197              2943             10               1        1475402  41831
# 198              8283              9               0        1612833  49625
# 199              1484             18               1        1952897  54938
#
# [200 rows x 10 columns]

# %%
dataset.shape
# Out:
# (200, 10)

# %%
dataset.isnull().sum()
# Out:
# Shop_ID             0
# Mall_Name           0
# City                0
# Floor               0
# Shop_Size_sqft      0
# Footfall_per_day    0
# Nearby_Brands       0
# Has_Food_Court      0
# Monthly_Sales       0
# Rent                0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Shop_ID           200 non-null    object
#  1   Mall_Name         200 non-null    object
#  2   City              200 non-null    object
#  3   Floor             200 non-null    int64
#  4   Shop_Size_sqft    200 non-null    int64
#  5   Footfall_per_day  200 non-null    int64
#  6   Nearby_Brands     200 non-null    int64
#  7   Has_Food_Court    200 non-null    int64
#  8   Monthly_Sales     200 non-null    int64
#  9   Rent              200 non-null    int64
# dtypes: int64(7), object(3)
# memory usage: 15.8+ KB

# %%
dataset=dataset.drop("Shop_ID",axis=1)
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#      Floor  Shop_Size_sqft  Footfall_per_day  Nearby_Brands  Has_Food_Court  \
# 0        2             352              6311              2               0
# 1        4            2961               802             16               0
# 2        0            1402              1138              9               0
# 3        4            1849               555             12               0
# 4        3            1400              9217             13               1
# ..     ...             ...               ...            ...             ...
# 195      4            1430               845              3               1
# 196      4            2205              9054             10               0
# 197      4             774              2943             10               1
# 198      4            2040              8283              9               0
# 199      4            1426              1484             18               1
#
#      Monthly_Sales   Rent  Mall_Name_Forum Mall  Mall_Name_Lulu Mall  \
# 0           962727  67310                     0                    1
# 1           549722  45221                     1                    0
# 2          1783693   3704                     0                    0
# 3           608924  68503                     1                    0
# 4          1834033  85666                     1                    0
# ..             ...    ...                   ...                  ...
# 195        1352549  44571                     0                    0
# 196        1381673  65858                     0                    0
# 197        1475402  41831                     0                    0
# 198        1612833  49625                     1                    0
# 199        1952897  54938                     0                    1
#
#      Mall_Name_Phoenix Marketcity  Mall_Name_VR Chennai  City_Chennai  \
# 0                               0                     0             0
# 1                               0                     0             1
# 2                               0                     1             0
# 3                               0                     0             0
# 4                               0                     0             0
# ..                            ...                   ...           ...
# 195                             0                     1             0
# 196                             0                     1             0
# 197                             1                     0             1
# 198                             0                     0             0
# 199                             0                     0             0
#
#      City_Delhi  City_Kochi  City_Mumbai
# 0             1           0            0
# 1             0           0            0
# 2             0           0            1
# 3             0           0            1
# 4             0           0            0
# ..          ...         ...          ...
# 195           0           1            0
# 196           0           1            0
# 197           0           0            0
# 198           0           0            0
# 199           1           0            0
#
# [200 rows x 15 columns]

# %%
dataset.columns
# Out:
# Index(['Floor', 'Shop_Size_sqft', 'Footfall_per_day', 'Nearby_Brands',
#        'Has_Food_Court', 'Monthly_Sales', 'Rent', 'Mall_Name_Forum Mall',
#        'Mall_Name_Lulu Mall', 'Mall_Name_Phoenix Marketcity',
#        'Mall_Name_VR Chennai', 'City_Chennai', 'City_Delhi', 'City_Kochi',
#        'City_Mumbai'],
#       dtype='object')

# %%
indep_X=dataset.drop("Rent", axis=1)
indep_X
# Out:
#      Floor  Shop_Size_sqft  Footfall_per_day  Nearby_Brands  Has_Food_Court  \
# 0        2             352              6311              2               0
# 1        4            2961               802             16               0
# 2        0            1402              1138              9               0
# 3        4            1849               555             12               0
# 4        3            1400              9217             13               1
# ..     ...             ...               ...            ...             ...
# 195      4            1430               845              3               1
# 196      4            2205              9054             10               0
# 197      4             774              2943             10               1
# 198      4            2040              8283              9               0
# 199      4            1426              1484             18               1
#
#      Monthly_Sales  Mall_Name_Forum Mall  Mall_Name_Lulu Mall  \
# 0           962727                     0                    1
# 1           549722                     1                    0
# 2          1783693                     0                    0
# 3           608924                     1                    0
# 4          1834033                     1                    0
# ..             ...                   ...                  ...
# 195        1352549                     0                    0
# 196        1381673                     0                    0
# 197        1475402                     0                    0
# 198        1612833                     1                    0
# 199        1952897                     0                    1
#
#      Mall_Name_Phoenix Marketcity  Mall_Name_VR Chennai  City_Chennai  \
# 0                               0                     0             0
# 1                               0                     0             1
# 2                               0                     1             0
# 3                               0                     0             0
# 4                               0                     0             0
# ..                            ...                   ...           ...
# 195                             0                     1             0
# 196                             0                     1             0
# 197                             1                     0             1
# 198                             0                     0             0
# 199                             0                     0             0
#
#      City_Delhi  City_Kochi  City_Mumbai
# 0             1           0            0
# 1             0           0            0
# 2             0           0            1
# 3             0           0            1
# 4             0           0            0
# ..          ...         ...          ...
# 195           0           1            0
# 196           0           1            0
# 197           0           0            0
# 198           0           0            0
# 199           1           0            0
#
# [200 rows x 14 columns]

# %%
dep_Y=dataset["Rent"]
dep_Y
# Out:
# 0      67310
# 1      45221
# 2       3704
# 3      68503
# 4      85666
#        ...
# 195    44571
# 196    65858
# 197    41831
# 198    49625
# 199    54938
# Name: Rent, Length: 200, dtype: int64

# %% [markdown]
# ## Univariate

# %%
for columnName in dataset.columns:
    print(columnName)
# Out:
# Floor
# Shop_Size_sqft
# Footfall_per_day
# Nearby_Brands
# Has_Food_Court
# Monthly_Sales
# Rent
# Mall_Name_Forum Mall
# Mall_Name_Lulu Mall
# Mall_Name_Phoenix Marketcity
# Mall_Name_VR Chennai
# City_Chennai
# City_Delhi
# City_Kochi
# City_Mumbai

# %%
from Univariate import univariate

# %%
qual,quan=univariate.QuanQual(dataset)

# %%
quan
# Out:
# ['Floor',
#  'Shop_Size_sqft',
#  'Footfall_per_day',
#  'Nearby_Brands',
#  'Has_Food_Court',
#  'Monthly_Sales',
#  'Rent',
#  'Mall_Name_Forum Mall',
#  'Mall_Name_Lulu Mall',
#  'Mall_Name_Phoenix Marketcity',
#  'Mall_Name_VR Chennai',
#  'City_Chennai',
#  'City_Delhi',
#  'City_Kochi',
#  'City_Mumbai']

# %%
descriptive=pd.DataFrame()

# %%
univariate.Univariate(dataset,quan)
# Out:
#              Floor Shop_Size_sqft Footfall_per_day Nearby_Brands  \
# Mean         2.135        1542.19         5001.405        10.135
# Median         2.0         1503.0           4806.5          10.0
# Mode             4           1178             6871            18
# Q1:25%         1.0          820.0          2518.75          5.75
# Q2:50%         2.0         1503.0           4806.5          10.0
# Q3:75%         4.0         2255.5          7384.25          15.0
# 99%            4.0        2991.01          9861.83          19.0
# Q4:100%        4.0         2995.0           9946.0          19.0
# IQR            3.0         1435.5           4865.5          9.25
# 1.5rule        4.5        2153.25          7298.25        13.875
# Lesser        -3.5       -1333.25          -4779.5        -8.125
# Greater        8.5        4408.75          14682.5        28.875
# Min              0            159              505             2
# Max              4           2995             9946            19
# Var       2.187714  721926.174774   7885776.242186     28.137462
# Std       1.479092     849.662389      2808.162432      5.304476
# kurtosis -1.408197      -1.207227        -1.261538     -1.181568
# skew     -0.122058        0.09004         0.085751      0.090896
#
#          Has_Food_Court        Monthly_Sales              Rent  \
# Mean              0.455          1010031.305         51942.225
# Median              0.0            1025155.5           49631.0
# Mode                  0                57906             26389
# Q1:25%              0.0             536851.0          33991.25
# Q2:50%              0.0            1025155.5           49631.0
# Q3:75%              1.0           1426538.75          68451.25
# 99%                 1.0           1971410.59          112844.6
# Q4:100%             1.0            1996793.0          134727.0
# IQR                 1.0            889687.75           34460.0
# 1.5rule             1.5          1334531.625           51690.0
# Lesser             -1.5          -797680.625         -17698.75
# Greater             2.5          2761070.375         120141.25
# Min                   0                57906             -7676
# Max                   1              1996793            134727
# Var            0.249221  318009862163.177856  669493302.657663
# Std             0.49922        563923.631499      25874.568647
# kurtosis      -1.986808            -1.129325          0.023517
# skew           0.182102              0.08928          0.222515
#
#          Mall_Name_Forum Mall Mall_Name_Lulu Mall  \
# Mean                     0.18               0.245
# Median                    0.0                 0.0
# Mode                        0                   0
# Q1:25%                    0.0                 0.0
# Q2:50%                    0.0                 0.0
# Q3:75%                    0.0                 0.0
# 99%                       1.0                 1.0
# Q4:100%                   1.0                 1.0
# IQR                       0.0                 0.0
# 1.5rule                   0.0                 0.0
# Lesser                    0.0                 0.0
# Greater                   0.0                 0.0
# Min                         0                   0
# Max                         1                   1
# Var                  0.148342            0.185905
# Std                  0.385152            0.431166
# kurtosis              0.82541           -0.578372
# skew                 1.678468            1.194786
#
#          Mall_Name_Phoenix Marketcity Mall_Name_VR Chennai City_Chennai  \
# Mean                            0.215                0.185        0.195
# Median                            0.0                  0.0          0.0
# Mode                                0                    0            0
# Q1:25%                            0.0                  0.0          0.0
# Q2:50%                            0.0                  0.0          0.0
# Q3:75%                            0.0                  0.0          0.0
# 99%                               1.0                  1.0          1.0
# Q4:100%                           1.0                  1.0          1.0
# IQR                               0.0                  0.0          0.0
# 1.5rule                           0.0                  0.0          0.0
# Lesser                            0.0                  0.0          0.0
# Greater                           0.0                  0.0          0.0
# Min                                 0                    0            0
# Max                                 1                    1            1
# Var                          0.169623             0.151533     0.157764
# Std                          0.411853             0.389272     0.397195
# kurtosis                    -0.046249             0.679109     0.410482
# skew                         1.397968             1.634753     1.551283
#
#          City_Delhi City_Kochi City_Mumbai
# Mean           0.19       0.17       0.225
# Median          0.0        0.0         0.0
# Mode              0          0           0
# Q1:25%          0.0        0.0         0.0
# Q2:50%          0.0        0.0         0.0
# Q3:75%          0.0        0.0         0.0
# 99%             1.0        1.0         1.0
# Q4:100%         1.0        1.0         1.0
# IQR             0.0        0.0         0.0
# 1.5rule         0.0        0.0         0.0
# Lesser          0.0        0.0         0.0
# Greater         0.0        0.0         0.0
# Min               0          0           0
# Max               1          1           1
# Var        0.154673   0.141809    0.175251
# Std        0.393285   0.376575     0.41863
# kurtosis   0.541007    1.14546   -0.241375
# skew       1.592387    1.77034    1.327079

# %%
univariate.freqTable("Monthly_Sales",dataset)
# Out:
#      Unique_values  Frequency  Relative_Frequency    Cumsum
# 0           962727          1            0.009709  0.009709
# 1          1990873          1            0.009709  0.019417
# 2          1776470          1            0.009709  0.029126
# 3          1293268          1            0.009709  0.038835
# 4            98874          1            0.009709  0.048544
# ..             ...        ...                 ...       ...
# 195        1192953          1            0.009709  1.902913
# 196        1914200          1            0.009709  1.912621
# 197        1931550          1            0.009709  1.922330
# 198        1927528          1            0.009709  1.932039
# 199        1952897          1            0.009709  1.941748
#
# [200 rows x 4 columns]

# %%
univariate.get_pdf_probability(dataset['Rent'],25000,50000)
# Out:
# Mean=51942.225, Standard Deviation=25874.569
# The area between range(25000,50000):0.32120224864743224
# 0.32120224864743224

# %% [markdown]
# ## Bivariate

# %%
dataset.select_dtypes(include='number').cov()
# Out:
#                                      Floor  Shop_Size_sqft  Footfall_per_day  \
# Floor                             2.187714    3.910487e+01      5.667692e+02
# Shop_Size_sqft                   39.104874    7.219262e+05     -3.572773e+04
# Footfall_per_day                566.769171   -3.572773e+04      7.885776e+06
# Nearby_Brands                    -0.787161    4.722548e+01     -3.977333e+02
# Has_Food_Court                    0.063894    3.418950e+01     -3.577817e+01
# Monthly_Sales                -12196.051432   -7.012619e+07      7.811129e+07
# Rent                           -954.769221    9.641141e+06      1.161789e+07
# Mall_Name_Forum Mall              0.071055   -1.622533e+01      6.753980e+01
# Mall_Name_Lulu Mall               0.011985    7.884422e-02     -1.685671e+02
# Mall_Name_Phoenix Marketcity     -0.009070    1.684337e+01      1.672090e+02
# Mall_Name_VR Chennai             -0.020075   -2.355291e+01     -9.421098e+01
# City_Chennai                      0.058970    3.324417e+01     -1.249839e+02
# City_Delhi                       -0.020754   -6.357889e+00      4.584226e+01
# City_Kochi                        0.012111    1.501276e+01      8.961925e+01
# City_Mumbai                      -0.025503   -9.917337e+00      1.650138e+01
#
#                               Nearby_Brands  Has_Food_Court  Monthly_Sales  \
# Floor                             -0.787161        0.063894  -1.219605e+04
# Shop_Size_sqft                    47.225477       34.189497  -7.012619e+07
# Footfall_per_day                -397.733342      -35.778166   7.811129e+07
# Nearby_Brands                     28.137462        0.063894   1.176238e+05
# Has_Food_Court                     0.063894        0.249221  -1.731842e+04
# Monthly_Sales                 117623.752588   -17318.415854   3.180099e+11
# Rent                           19320.768467     3004.791583  -2.564084e+09
# Mall_Name_Forum Mall               0.020804       -0.006935   3.121069e+04
# Mall_Name_Lulu Mall                0.052186       -0.011533  -2.495419e+04
# Mall_Name_Phoenix Marketcity      -0.154799        0.027312   1.653924e+04
# Mall_Name_VR Chennai              -0.120578       -0.024296  -1.214544e+03
# City_Chennai                      -0.051583        0.001281  -2.057963e+04
# City_Delhi                        -0.096131        0.028693   7.960359e+03
# City_Kochi                         0.298543       -0.022462  -2.592173e+03
# City_Mumbai                       -0.161181       -0.022487   2.717243e+04
#
#                                       Rent  Mall_Name_Forum Mall  \
# Floor                        -9.547692e+02              0.071055
# Shop_Size_sqft                9.641141e+06            -16.225327
# Footfall_per_day              1.161789e+07             67.539799
# Nearby_Brands                 1.932077e+04              0.020804
# Has_Food_Court                3.004792e+03             -0.006935
# Monthly_Sales                -2.564084e+09          31210.693568
# Rent                          6.694933e+08             94.823618
# Mall_Name_Forum Mall          9.482362e+01              0.148342
# Mall_Name_Lulu Mall           5.719144e+02             -0.044322
# Mall_Name_Phoenix Marketcity  8.208204e+01             -0.038894
# Mall_Name_VR Chennai         -8.352177e+02             -0.033467
# City_Chennai                  5.661921e+02             -0.010151
# City_Delhi                    2.762538e+01              0.015879
# City_Kochi                    3.563492e+01             -0.005628
# City_Mumbai                  -5.745685e+02             -0.010553
#
#                               Mall_Name_Lulu Mall  \
# Floor                                    0.011985
# Shop_Size_sqft                           0.078844
# Footfall_per_day                      -168.567060
# Nearby_Brands                            0.052186
# Has_Food_Court                          -0.011533
# Monthly_Sales                       -24954.190678
# Rent                                   571.914447
# Mall_Name_Forum Mall                    -0.044322
# Mall_Name_Lulu Mall                      0.185905
# Mall_Name_Phoenix Marketcity            -0.052940
# Mall_Name_VR Chennai                    -0.045553
# City_Chennai                             0.022337
# City_Delhi                              -0.016633
# City_Kochi                              -0.006683
# City_Mumbai                              0.004899
#
#                               Mall_Name_Phoenix Marketcity  \
# Floor                                            -0.009070
# Shop_Size_sqft                                   16.843367
# Footfall_per_day                                167.208970
# Nearby_Brands                                    -0.154799
# Has_Food_Court                                    0.027312
# Monthly_Sales                                 16539.235603
# Rent                                             82.082035
# Mall_Name_Forum Mall                             -0.038894
# Mall_Name_Lulu Mall                              -0.052940
# Mall_Name_Phoenix Marketcity                      0.169623
# Mall_Name_VR Chennai                             -0.039975
# City_Chennai                                     -0.011985
# City_Delhi                                       -0.000854
# City_Kochi                                        0.003467
# City_Mumbai                                       0.016709
#
#                               Mall_Name_VR Chennai  City_Chennai   City_Delhi  \
# Floor                                    -0.020075      0.058970    -0.020754
# Shop_Size_sqft                          -23.552915     33.244171    -6.357889
# Footfall_per_day                        -94.210980   -124.983894    45.842261
# Nearby_Brands                            -0.120578     -0.051583    -0.096131
# Has_Food_Court                           -0.024296      0.001281     0.028693
# Monthly_Sales                         -1214.544146 -20579.627613  7960.358844
# Rent                                   -835.217714    566.192085    27.625377
# Mall_Name_Forum Mall                     -0.033467     -0.010151     0.015879
# Mall_Name_Lulu Mall                      -0.045553      0.022337    -0.016633
# Mall_Name_Phoenix Marketcity             -0.039975     -0.011985    -0.000854
# Mall_Name_VR Chennai                      0.151533     -0.011131    -0.005176
# City_Chennai                             -0.011131      0.157764    -0.037236
# City_Delhi                               -0.005176     -0.037236     0.154673
# City_Kochi                                0.008593     -0.033317    -0.032462
# City_Mumbai                               0.008417     -0.044095    -0.042965
#
#                                City_Kochi   City_Mumbai
# Floor                            0.012111     -0.025503
# Shop_Size_sqft                  15.012764     -9.917337
# Footfall_per_day                89.619246     16.501382
# Nearby_Brands                    0.298543     -0.161181
# Has_Food_Court                  -0.022462     -0.022487
# Monthly_Sales                -2592.172714  27172.433543
# Rent                            35.634925   -574.568467
# Mall_Name_Forum Mall            -0.005628     -0.010553
# Mall_Name_Lulu Mall             -0.006683      0.004899
# Mall_Name_Phoenix Marketcity     0.003467      0.016709
# Mall_Name_VR Chennai             0.008593      0.008417
# City_Chennai                    -0.033317     -0.044095
# City_Delhi                      -0.032462     -0.042965
# City_Kochi                       0.141809     -0.038442
# City_Mumbai                     -0.038442      0.175251

# %%
dataset.select_dtypes(include="number").corr()
# Out:
#                                  Floor  Shop_Size_sqft  Footfall_per_day  \
# Floor                         1.000000        0.031116          0.136455
# Shop_Size_sqft                0.031116        1.000000         -0.014974
# Footfall_per_day              0.136455       -0.014974          1.000000
# Nearby_Brands                -0.100329        0.010478         -0.026701
# Has_Food_Court                0.086532        0.080604         -0.025521
# Monthly_Sales                -0.014622       -0.146357          0.049325
# Rent                         -0.024948        0.438540          0.159894
# Mall_Name_Forum Mall          0.124730       -0.049581          0.062446
# Mall_Name_Lulu Mall           0.018793        0.000215         -0.139221
# Mall_Name_Phoenix Marketcity -0.014890        0.048133          0.144576
# Mall_Name_VR Chennai         -0.034867       -0.071211         -0.086184
# City_Chennai                  0.100376        0.098507         -0.112054
# City_Delhi                   -0.035677       -0.019026          0.041508
# City_Kochi                    0.021743        0.046920          0.084748
# City_Mumbai                  -0.041187       -0.027882          0.014037
#
#                               Nearby_Brands  Has_Food_Court  Monthly_Sales  \
# Floor                             -0.100329        0.086532      -0.014622
# Shop_Size_sqft                     0.010478        0.080604      -0.146357
# Footfall_per_day                  -0.026701       -0.025521       0.049325
# Nearby_Brands                      1.000000        0.024128       0.039322
# Has_Food_Court                     0.024128        1.000000      -0.061517
# Monthly_Sales                      0.039322       -0.061517       1.000000
# Rent                               0.140770        0.232621      -0.175727
# Mall_Name_Forum Mall               0.010183       -0.036066       0.143698
# Mall_Name_Lulu Mall                0.022817       -0.053579      -0.102631
# Mall_Name_Phoenix Marketcity      -0.070857        0.132835       0.071212
# Mall_Name_VR Chennai              -0.058395       -0.125025      -0.005533
# City_Chennai                      -0.024483        0.006462      -0.091878
# City_Delhi                        -0.046080        0.146145       0.035893
# City_Kochi                         0.149456       -0.119484      -0.012207
# City_Mumbai                       -0.072584       -0.107601       0.115101
#
#                                   Rent  Mall_Name_Forum Mall  \
# Floor                        -0.024948              0.124730
# Shop_Size_sqft                0.438540             -0.049581
# Footfall_per_day              0.159894              0.062446
# Nearby_Brands                 0.140770              0.010183
# Has_Food_Court                0.232621             -0.036066
# Monthly_Sales                -0.175727              0.143698
# Rent                          1.000000              0.009515
# Mall_Name_Forum Mall          0.009515              1.000000
# Mall_Name_Lulu Mall           0.051264             -0.266894
# Mall_Name_Phoenix Marketcity  0.007703             -0.245196
# Mall_Name_VR Chennai         -0.082923             -0.223222
# City_Chennai                  0.055092             -0.066353
# City_Delhi                    0.002715              0.104832
# City_Kochi                    0.003657             -0.038804
# City_Mumbai                  -0.053044             -0.065449
#
#                               Mall_Name_Lulu Mall  \
# Floor                                    0.018793
# Shop_Size_sqft                           0.000215
# Footfall_per_day                        -0.139221
# Nearby_Brands                            0.022817
# Has_Food_Court                          -0.053579
# Monthly_Sales                           -0.102631
# Rent                                     0.051264
# Mall_Name_Forum Mall                    -0.266894
# Mall_Name_Lulu Mall                      1.000000
# Mall_Name_Phoenix Marketcity            -0.298122
# Mall_Name_VR Chennai                    -0.271404
# City_Chennai                             0.130428
# City_Delhi                              -0.098089
# City_Kochi                              -0.041162
# City_Mumbai                              0.027144
#
#                               Mall_Name_Phoenix Marketcity  \
# Floor                                            -0.014890
# Shop_Size_sqft                                    0.048133
# Footfall_per_day                                  0.144576
# Nearby_Brands                                    -0.070857
# Has_Food_Court                                    0.132835
# Monthly_Sales                                     0.071212
# Rent                                              0.007703
# Mall_Name_Forum Mall                             -0.245196
# Mall_Name_Lulu Mall                              -0.298122
# Mall_Name_Phoenix Marketcity                      1.000000
# Mall_Name_VR Chennai                             -0.249340
# City_Chennai                                     -0.073264
# City_Delhi                                       -0.005274
# City_Kochi                                        0.022356
# City_Mumbai                                       0.096909
#
#                               Mall_Name_VR Chennai  City_Chennai  City_Delhi  \
# Floor                                    -0.034867      0.100376   -0.035677
# Shop_Size_sqft                           -0.071211      0.098507   -0.019026
# Footfall_per_day                         -0.086184     -0.112054    0.041508
# Nearby_Brands                            -0.058395     -0.024483   -0.046080
# Has_Food_Court                           -0.125025      0.006462    0.146145
# Monthly_Sales                            -0.005533     -0.091878    0.035893
# Rent                                     -0.082923      0.055092    0.002715
# Mall_Name_Forum Mall                     -0.223222     -0.066353    0.104832
# Mall_Name_Lulu Mall                      -0.271404      0.130428   -0.098089
# Mall_Name_Phoenix Marketcity             -0.249340     -0.073264   -0.005274
# Mall_Name_VR Chennai                      1.000000     -0.071989   -0.033808
# City_Chennai                             -0.071989      1.000000   -0.238371
# City_Delhi                               -0.033808     -0.238371    1.000000
# City_Kochi                                0.058619     -0.222743   -0.219189
# City_Mumbai                               0.051651     -0.265192   -0.260960
#
#                               City_Kochi  City_Mumbai
# Floor                           0.021743    -0.041187
# Shop_Size_sqft                  0.046920    -0.027882
# Footfall_per_day                0.084748     0.014037
# Nearby_Brands                   0.149456    -0.072584
# Has_Food_Court                 -0.119484    -0.107601
# Monthly_Sales                  -0.012207     0.115101
# Rent                            0.003657    -0.053044
# Mall_Name_Forum Mall           -0.038804    -0.065449
# Mall_Name_Lulu Mall            -0.041162     0.027144
# Mall_Name_Phoenix Marketcity    0.022356     0.096909
# Mall_Name_VR Chennai            0.058619     0.051651
# City_Chennai                   -0.222743    -0.265192
# City_Delhi                     -0.219189    -0.260960
# City_Kochi                      1.000000    -0.243852
# City_Mumbai                    -0.243852     1.000000

# %%
sns.pairplot(dataset[['Floor','Shop_Size_sqft','Footfall_per_day','Nearby_Brands',
             'Has_Food_Court','Monthly_Sales','Rent']])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):
    vif=pd.DataFrame()
    vif["variables"]=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values, i) for i in range (X.shape[1])]
    return (vif)

# %%
calc_vif(dataset[["Floor","Shop_Size_sqft","Footfall_per_day","Nearby_Brands","Has_Food_Court","Monthly_Sales"]])
# Out:
#           variables       VIF
# 0             Floor  2.902708
# 1    Shop_Size_sqft  3.434641
# 2  Footfall_per_day  3.667118
# 3     Nearby_Brands  3.693007
# 4    Has_Food_Court  1.809598
# 5     Monthly_Sales  3.381661

# %% [markdown]
# ## Model Creation

# %%
def selectkbest(indep_X,dep_Y,n):
        test = SelectKBest(score_func=chi2, k=n)
        fit1= test.fit(indep_X,dep_Y)       
        selectk_features = fit1.transform(indep_X)
        return selectk_features

def split_scalar(indep_X,dep_Y):
      
    X_train,X_test,Y_train,Y_test=train_test_split(indep_X,dep_Y, test_size=0.30,random_state=0)
    sc=StandardScaler()
    X_train=sc.fit_transform(X_train)
    X_test=sc.transform(X_test)
    return X_train,X_test,Y_train,Y_test

def r2_prediction(regressor,X_test,Y_test):
     y_pred = regressor.predict(X_test)
     from sklearn.metrics import r2_score
     r2=r2_score(Y_test,y_pred)
     return r2
 
def Linear(X_train,Y_train,X_test):       
        
        from sklearn.linear_model import Ridge
        param_dist = {'alpha': uniform(0, 10)}
        search = RandomizedSearchCV(
            Ridge(),
            param_distributions=param_dist,
            n_iter=10,
            scoring='r2',
            cv=3,
            random_state=42
        )
        search.fit(X_train, Y_train)
        best_model = search.best_estimator_
        r2 = r2_prediction(best_model, X_test, Y_test)
        return r2  
    
def svm_linear(X_train,Y_train,X_test):
                
        from sklearn.svm import SVR
        param_dist = {'C': np.logspace(-2, 2, 5),'epsilon': [0.01, 0.1, 0.2],'kernel': ['linear']}
        search = RandomizedSearchCV(SVR(), param_distributions=param_dist, n_iter=10, cv=3,
                                scoring='r2', random_state=42, n_jobs=-1)
        search.fit(X_train, Y_train)
        best_model = search.best_estimator_
        r2=r2_prediction(best_model, X_test, Y_test)
        return  r2  
    
def svm_NL(X_train,Y_train,X_test):
                
        from sklearn.svm import SVR
        param_dist = {'C': np.logspace(-2, 2, 5),'gamma': ['scale', 0.01, 0.1, 1],'epsilon': [0.01, 0.1, 0.2],'kernel': ['rbf']}
        search = RandomizedSearchCV(SVR(), param_distributions=param_dist, n_iter=10, cv=3,
                                scoring='r2', random_state=42, n_jobs=-1)
        search.fit(X_train, Y_train)
        best_model = search.best_estimator_
        r2=r2_prediction(best_model,X_test,Y_test)
        return  r2       

def Decision(X_train,Y_train,X_test):
                
        from sklearn.tree import DecisionTreeRegressor
        param_dist = {'max_depth': [None, 5, 10, 20],'min_samples_split': [2, 5, 10],'min_samples_leaf': [1, 2, 4],
                      'criterion': ['squared_error', 'friedman_mse']}
        search = RandomizedSearchCV(DecisionTreeRegressor(random_state=42),param_distributions=param_dist, n_iter=10, cv=3,
                                    scoring='r2', random_state=42, n_jobs=-1)
        search.fit(X_train, Y_train)
        best_model = search.best_estimator_
        r2=r2_prediction(best_model,X_test,Y_test)
        return  r2       

def random(X_train,Y_train,X_test):       
        
        from sklearn.ensemble import RandomForestRegressor
        param_dist = {'n_estimators': [50, 100, 200],'max_depth': [None, 10, 20],'min_samples_split': [2, 5],'min_samples_leaf': [1, 2],
                       'bootstrap': [True, False]}   
        search = RandomizedSearchCV(RandomForestRegressor(random_state=42),param_distributions=param_dist, n_iter=10, cv=3,
                                    scoring='r2', random_state=42, n_jobs=-1)
        search.fit(X_train, Y_train)
        best_model = search.best_estimator_
        r2=r2_prediction(best_model,X_test,Y_test)
        return  r2 
        
def selectk_regression(acclin,accsvml,accsvmnl,accdes,accrf): 
    
    dataframe=pd.DataFrame(index=['ChiSquare'],columns=['Linear','SVMl','SVMnl','Decision','Random'])

    for number,idex in enumerate(dataframe.index):
        
        dataframe['Linear'][idex]=acclin[number]       
        dataframe['SVMl'][idex]=accsvml[number]
        dataframe['SVMnl'][idex]=accsvmnl[number]
        dataframe['Decision'][idex]=accdes[number]
        dataframe['Random'][idex]=accrf[number]
    return dataframe

# %%
kbest=selectkbest(indep_X,dep_Y,7)      
X_train, X_test, Y_train, Y_test=split_scalar(kbest,dep_Y)  

acclin=[]
accsvml=[]
accsvmnl=[]
accdes=[]
accrf=[]

# %%
r2_lin=Linear(X_train,Y_train,X_test)
acclin.append(r2_lin)
    
r2_sl=svm_linear(X_train,Y_train,X_test)    
accsvml.append(r2_sl)
    
r2_NL=svm_NL(X_train,Y_train,X_test)
accsvmnl.append(r2_NL)
    
r2_d=Decision(X_train,Y_train,X_test)
accdes.append(r2_d)
    
r2_r=random(X_train,Y_train,X_test)
accrf.append(r2_r)

    
result=selectk_regression(acclin,accsvml,accsvmnl,accdes,accrf)

# %%
result1 = result
result1
#4
# Out:
#             Linear      SVMl     SVMnl  Decision    Random
# ChiSquare  0.24543  0.074636 -0.004327 -0.218963  0.123121

# %%
result2 = result
result2
#5
# Out:
#              Linear      SVMl     SVMnl  Decision    Random
# ChiSquare  0.225526  0.078465 -0.007145 -0.218963  0.126925

# %%
result3 = result
result3
#7
# Out:
#              Linear      SVMl     SVMnl  Decision    Random
# ChiSquare  0.185558  0.068297 -0.009351 -0.141034  0.117826

# %%
results = [result1, result2, result3]   # add as many as we have

summary = []

for i, df in enumerate(results, start=5):   # since numbering starts at #5
    best_model = df.max().idxmax()          # best column name (model)
    best_score = df.max().max()             # best R² or accuracy
    summary.append({
        "Result_No": f"# {i}",
        "Best_Model": best_model,
        "Best_Score": best_score
    })

summary_df = pd.DataFrame(summary)
print(summary_df)
# Out:
#   Result_No Best_Model  Best_Score
# 0       # 5     Linear    0.245430
# 1       # 6     Linear    0.225526
# 2       # 7     Linear    0.185558
