# %%
import pandas as pd
import numpy as np
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_RFE_restaurant_data.sav",'rb'))
result=loaded_model.predict([[61, 73.65, 1]])
result
# Out:
# array([1010356.305])
